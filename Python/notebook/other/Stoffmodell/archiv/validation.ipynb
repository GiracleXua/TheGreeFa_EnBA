# %%
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df_ori = pd.read_excel('MgCL2_data.xlsx', sheet_name='Tabelle1')

# %%
df_ori = df_ori.set_index('molality')

# %%
df_ori.to_csv('mgcl2.csv')

# %%
df_ori.plot()

# %%
df_ori_cp = pd.read_excel('MgCL2_data.xlsx', sheet_name='Tabelle1')

# %%
df_ori_cp.set_index('molality')
# Out:
#           exp 298  sim 298  exp 323  sim 323  exp 348  sim 348  exp 373  \
# molality
# 0.00000    4.1779   4.1821   4.1790   4.1798   4.1911   4.1917   4.2143
# 0.10844    4.1111   4.1213   4.1150   4.1219   4.1262   4.1347   4.1462
# 0.19711    4.0590   4.0757   4.0654   4.0759   4.0766   4.0894   4.0946
# 0.28186    4.0115   4.0317   4.0199   4.0329   4.0308   4.0471   4.0469
# 0.38842    3.9533   3.9778   3.9644   3.9803   3.9751   3.9953   3.9894
# 0.52775    3.8807   3.9096   3.8957   3.9140   3.9040   3.9290   3.9182
#
#           sim 373
# molality
# 0.00000    4.2167
# 0.10844    4.1600
# 0.19711    4.1149
# 0.28186    4.0729
# 0.38842    4.0216
# 0.52775    3.9566

# %%
df_ori_cp.set_index('molality').to_csv('mgcl2_cp.csv')
